# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import random as rng

num_test_outputs = 10
rng.random(size=num_test_outputs)

def my_uniform_chisq(bin_values, bin_expectations):
    num_bins = len(bin_values)
    chi_square = sum( ( ((bin_values[i] - bin_expectations[i])**2) / bin_values[i] ) for i in range(num_bins))
    return(chi_square)
samples=1000
num_bins=10

chisq_list=[]
x=0
while x<25:
    data=rng.random(samples)
    bin_values, bin_edges, patches = plt.hist(data,num_bins)
    plt.show()
    print(bin_values)
    bin_expectations = [samples/num_bins] *num_bins
    print(bin_expectations)
    chisq = my_uniform_chisq(bin_values, bin_expectations)
    print(chisq)
    chisq_list.append(chisq)
    x=x+1 #so this wont go on forever
         
print(chisq_list)
# Out:
# [ 89.  96.  92. 109. 105. 102. 102. 104.  89. 112.]
# [100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0]
# 6.0806262804349585
# [100.  98. 108.  91.  96.  99.  91.  92. 103. 122.]
# [100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0]
# 7.340640305554503
# [112.  91.  92.  96. 108.  87. 104. 100. 107. 103.]
# [100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0]
# 6.272433064485161
# [113.  97. 112. 104.  87.  96.  88. 107. 102.  94.]
# [100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0]
# 7.653616539528914
# [ 83.  98.  95. 107. 108. 121.  86.  90. 100. 112.]
# [100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0]
# 13.156961713377877
# [100. 101.  84. 107. 115. 114.  88.  91. 103.  97.]
# [100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0]
# 9.897919620101037
# [ 85.  99. 109. 104.  93. 100. 101. 102.  88. 119.]
# ...

# %%
#problem 2
import numpy as np
import matplotlib.pyplot as plt
from numpy import random as rng

#personal rng, like coin flips?        
def seedLCG(initVal):
    global rand
    rand = initVal

def lcg():
    a = 1140671485
    c = 128201163
    m = 2**24
    global rand
    rand = (a*rand + c) % m
    return rand

    seedLCG(1)

for i in range(10):
    print lcg()
    
    #For some reason, this keeps saying invalid syntax??
    
    #Ill try to continue with testing this..
def my_uniform_chisq(bin_values, bin_expectations):
    num_bins = len(bin_values)
    chi_square = sum( ( ((bin_values[i] - bin_expectations[i])**2) / bin_values[i] ) for i in range(num_bins))
    return(chi_square)
samples=1000
num_bins=10


chisq_list=[]
x=0
while x<100:
    data=rng.random(samples)
    bin_values, bin_edges, patches = plt.hist(data,num_bins)
    plt.show()
    print(bin_values)
    bin_expectations = [samples/num_bins] *num_bins
    print(bin_expectations)
    chisq = (bin_values, bin_expectations)
    print(chisq)
    chisq_list.append(chisq)
    x=x+1

        #Im a bit lost on testing this
# Out:
#   File "<ipython-input-42-3f11cb4f5fa8>", line 22
#     print lcg()
#             ^
# SyntaxError: invalid syntax

# %%
#2 basic rng
def LCG(seed, n, a=1664525, c=1013904223, m=2**32):
    numbers = []
    for i in xrange(n):
        seed = (a * seed + c) % m
        numbers.append(seed)

    return numbers

print LCG()
# Out:
#   File "<ipython-input-49-c6bc8f8872dc>", line 10
#     print LCG()
#             ^
# SyntaxError: invalid syntax

# %%
#Attempt at seeding
#3

def my_uniform_chisq(bin_values, bin_expectations):
    num_bins = len(bin_values)
    chi_square = sum( ( ((bin_values[i] - bin_expectations[i])**2) / bin_values[i] ) for i in range(num_bins))
    return(chi_square)
samples=1000
num_bins=10

chisq_list=[]
x=0
i=0
s=0
while x<30:
    
    rn_list=[]
while i<50:
    random.seed(s)
    rn = random.random()
    rn_list.append(rns)
    s=s+1
    i=i+1
    data=rn_list[]
    
        plt.figure(1)
    bin_values, bin_edges, patches = plt.hist(data,num_bins)
    plt.show()
    print(bin_values)
    bin_expectations = [samples/num_bins] *num_bins
    print(bin_expectations)
    chisq = (bin_values, bin_expectations)
    print(chisq)
    chisq_list.append(chisq)
    x=x+1
    i=0
    
    
    

i=0
s=0
rn_list=[]
while i<50:
    random.seed(s)
    rn = random.random()
    rn_list.append(rns)
    s=s+1
    i=i+1
print(rn_list)

x=list(range(1,51))
plt.scatter(x,rn_list)
plt.xlabel('rng test (x)')
plt.ylabel('random value')

plt.figure(2)
samples=50
x=np.sort(rn_list)
y=np.arrange(1, samples + 1)/samples
plt.axis([0,1,0,1])
plt.scatter(x,y)
# Out:
#   File "<ipython-input-54-b1ac9ad9ec61>", line 24
#     data=rn_list[]
#                  ^
# SyntaxError: invalid syntax

# %%
#sum problem, #4


from mpl_toolkits.mplot3d import Axes3D

nun_samples=100
three_d_list=[]
for i in range(num_samples):
    x=random.random(), random.random(), random.random())
    two_d_list.append(x)
vects=np.array(three_d_list)

fig=plt.figure()
ax = fig.add_subplot(111, projection='3d')

x=list(vects{[:,0])
y=list(vects[:,1])
z=list(vects[:,2])
ax.scatter(x,y,z)
ax.set_xlabel('X axis')
# Out:
#   File "<ipython-input-55-0a8ecbba078e>", line 6
#     x=random.random(), random.random(), random.random())
#                                                        ^
# SyntaxError: invalid syntax
